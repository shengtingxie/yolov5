# %%
import torch
from PIL import ImageGrab

# Model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')

# Image
im = ImageGrab.grab()  # take a screenshot

# Inference
results = model(im)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/archive/master.zip" to C:\Users\laoqi/.cache\torch\hub\master.zip
# YOLOv5  2022-10-16 Python-3.9.12 torch-1.11.0 CPU
#
# ...
#   0%|          | 0.00/14.1M [00:00<?, ?B/s]
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...

# %% [markdown]
# ![Fist_2_No_gesture_0_00a99912-19c1-478e-be27-d9a4579cdd7b.jpg](attachment:Fist_2_No_gesture_0_00a99912-19c1-478e-be27-d9a4579cdd7b.jpg)

# %%
results
# Out:
# YOLOv5 <class 'models.common.Detections'> instance
# image 1/1: 1200x1920 (no detections)
# Speed: 12.6ms pre-process, 291.6ms inference, 9.2ms NMS per image at shape (1, 3, 416, 640)

# %%
im = ImageGrab.grab()  # take a screenshot

# Inference
results = model(im, augment=augment, visualize=visualize)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 im = ImageGrab.grab()  # take a screenshot
#       3 # Inference
#       4 results = model(im, augment=augment, visualize=visualize)
#
# NameError: name 'ImageGrab' is not defined

# %%
results
# Out:
# YOLOv5 <class 'models.common.Detections'> instance
# image 1/1: 1200x1920 1 person
# Speed: 7.8ms pre-process, 197.3ms inference, 0.0ms NMS per image at shape (1, 3, 416, 640)

# %%
results[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 results[0]
#
# TypeError: 'Detections' object is not subscriptable

# %%
import torch
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')

# Image
im = 'https://ultralytics.com/images/zidane.jpg'

# Inference
results = model(im)
# Out:
# Using cache found in C:\Users\laoqi/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2022-10-16 Python-3.9.12 torch-1.11.0 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...

# %%
results.pandas().xyxy[0]['class']
# Out:
# 0     0
# 1    27
# 2     0
# 3    27
# Name: class, dtype: int64

# %%
results.pandas().xyxy[0][["class"]]
# Out:
#    class
# 0      0
# 1     27
# 2      0
# 3     27

# %%
results.pandas().xyxy[0].shape
# Out:
# (4, 7)

# %%
x=results.pandas().xyxy[0][["class"]].values

# %%
x[1][0]
# Out:
# 27

# %%
x[1][0]==27
# Out:
# True

# %%
results.pandas().xyxy[0][["class"]].shape[0]
# Out:
# 4
